# %%
import pandas as pd
import numpy as np

import string
import re

RANDOM = 42

# %% [markdown]
# # The haiku dataset: loading and initial cleaning
#
# This was obtained from the dataset created by Jeremy Neiman for use in his own haiku generation model, published in the last few days of 2018; Medium post <a href="https://towardsdatascience.com/generating-haiku-with-deep-learning-dbf5d18b4246">here</a> and Github for the dataset <a href="https://github.com/docmarionum1/haikurnn/tree/master/input/poems">here</a>.

# %%
haikus_df = pd.read_csv('./data/image_to_text/haikus.csv')

# %%
haikus_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143137 entries, 0 to 143136
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   0            143120 non-null  object
#  1   1            143123 non-null  object
#  2   2            142954 non-null  object
#  3   source       143137 non-null  object
#  4   0_syllables  143137 non-null  object
#  5   1_syllables  143137 non-null  object
#  6   2_syllables  143137 non-null  object
# dtypes: object(7)
# memory usage: 7.6+ MB

# %%
haikus_df.source.value_counts()
# Out:
# twaiku         111727
# img2poems       11808
# sballas          8142
# gutenberg        5524
# tempslibres      4800
# haikuzao         1136
# Name: source, dtype: int64

# %% [markdown]
# Neiman discardes the twaiku source from his final model because the poetry there appears to be low quality

# %%
haikus_notwitter_df = haikus_df[haikus_df.source != 'twaiku']

haikus_notwitter_df.source.value_counts()
# Out:
# img2poems      11808
# sballas         8142
# gutenberg       5524
# tempslibres     4800
# haikuzao        1136
# Name: source, dtype: int64

# %%
haikus_notwitter_df
# Out:
#                                       0  \
# 0                       Memorial Day --
# 1                         spring rain -
# 2                     spring moonset --
# 3                       sunny afternoon
# 4                         cinco de mayo
# ...                                 ...
# 31405  Jupiter's throne, so dishonestly
# 31406              Now, all intelligent
# 31407           They like to Form their
# 31408             Nor do the girls take
# 31409                None finds me ugly
#
#                                                     1  \
# 0                                   a shadow for each
# 1                                as the doctor speaks
# 2                                     a rice ball for
# 3                                  an old man lingers
# 4                                         horses roll
# ...                                               ...
# 31405  won, it was I who secured it: Color and ivory,
# 31406                                men look upon me
# 31407                        own image of me, just as
# 31408                 offense when they see me--by no
# 31409                              today, though I am
#
#                                                   2       source 0_syllables  \
# 0                                       white cross  tempslibres           5
# 1                                 i think of lilacs  tempslibres         2,3
# 2                                         breakfast  tempslibres         3,4
# 3                                  near the mailbox  tempslibres           5
# 4                                   in the shallows  tempslibres           5
# ...                                             ...          ...         ...
# 31405  marble and bronze, not to mention the poems.    gutenberg           9
# 31406                                  in kindness.    gutenberg           6
# 31407                            the poet has done.    gutenberg           5
# 31408                            means the matrons.    gutenberg           5
# 31409                           monstrously strong.    gutenberg           5
#
#       1_syllables 2_syllables
# 0               5           2
# 1               5           5
# 2               4           2
# 3               5           4
# 4               3           4
# ...           ...         ...
# 31405       13,14          11
# 31406           5           3
# 31407           7           5
# 31408           7           4
# 31409         5,6           4
#
# [31410 rows x 7 columns]

# %% [markdown]
# For the sake of simplicity, will only look at the lower syllable count where there are two values

# %%
syllable_cols = ['0_syllables', '1_syllables', '2_syllables']

for col in syllable_cols:
    haikus_notwitter_df[col] = haikus_notwitter_df[col].apply(lambda x: int(x.split(',')[0]))
# Out:
# C:\Users\vi_ci\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
haikus_notwitter_df
# Out:
#                                       0  \
# 0                       Memorial Day --
# 1                         spring rain -
# 2                     spring moonset --
# 3                       sunny afternoon
# 4                         cinco de mayo
# ...                                 ...
# 31405  Jupiter's throne, so dishonestly
# 31406              Now, all intelligent
# 31407           They like to Form their
# 31408             Nor do the girls take
# 31409                None finds me ugly
#
#                                                     1  \
# 0                                   a shadow for each
# 1                                as the doctor speaks
# 2                                     a rice ball for
# 3                                  an old man lingers
# 4                                         horses roll
# ...                                               ...
# 31405  won, it was I who secured it: Color and ivory,
# 31406                                men look upon me
# 31407                        own image of me, just as
# 31408                 offense when they see me--by no
# 31409                              today, though I am
#
#                                                   2       source  0_syllables  \
# 0                                       white cross  tempslibres            5
# 1                                 i think of lilacs  tempslibres            2
# 2                                         breakfast  tempslibres            3
# 3                                  near the mailbox  tempslibres            5
# 4                                   in the shallows  tempslibres            5
# ...                                             ...          ...          ...
# 31405  marble and bronze, not to mention the poems.    gutenberg            9
# 31406                                  in kindness.    gutenberg            6
# 31407                            the poet has done.    gutenberg            5
# 31408                            means the matrons.    gutenberg            5
# 31409                           monstrously strong.    gutenberg            5
#
#        1_syllables  2_syllables
# 0                5            2
# 1                5            5
# 2                4            2
# 3                5            4
# 4                3            4
# ...            ...          ...
# 31405           13           11
# 31406            5            3
# 31407            7            5
# 31408            7            4
# 31409            5            4
#
# [31410 rows x 7 columns]

# %% [markdown]
# Create a new column that has the whole text of the 3-line poems

# %%
haikus_notwitter_df['text'] = haikus_notwitter_df['0'] + ' ' + haikus_notwitter_df['1'] + ' ' + haikus_notwitter_df['2']
# Out:
# C:\Users\vi_ci\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ..and a column with all lower case and without punctuation

# %%
alphanumeric = lambda x: re.sub('\w*\d\w*', ' ', x)
punc_lower = lambda x: re.sub('[%s]' % re.escape(string.punctuation), ' ', x.lower())

haikus_notwitter_df['text_clean'] = haikus_notwitter_df.text.map(alphanumeric).map(punc_lower)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-4620b5eb7d20> in <module>
#       2 punc_lower = lambda x: re.sub('[%s]' % re.escape(string.punctuation), ' ', x.lower())
#       3
# ----> 4 haikus_notwitter_df['text_clean'] = haikus_notwitter_df.text.map(alphanumeric).map(punc_lower)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3628         dtype: object
#    3629         """
# -> 3630         new_values = super()._map_values(arg, na_action=na_action)
#    3631         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3632
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1143
#    1144         # mapper is a function
# -> 1145         new_values = map_f(values, mapper)
#    1146
#    1147         return new_values
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-34-4620b5eb7d20> in <lambda>(x)
# ----> 1 alphanumeric = lambda x: re.sub('\w*\d\w*', ' ', x)
#       2 punc_lower = lambda x: re.sub('[%s]' % re.escape(string.punctuation), ' ', x.lower())
#       3
#       4 haikus_notwitter_df['text_clean'] = haikus_notwitter_df.text.map(alphanumeric).map(punc_lower)
#
# ~\anaconda3\lib\re.py in sub(pattern, repl, string, count, flags)
#     190     a callable, it's passed the Match object and must return
#     191     a replacement string to be used."""
# --> 192     return _compile(pattern, flags).sub(repl, string, count)
#     193
#     194 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %% [markdown]
# Split into train and test (80/20)

# %%
from sklearn.model_selection import train_test_split

haikus_train_df, haikus_test_df = train_test_split(haikus_notwitter_df, test_size=0.2, random_state=RANDOM)

# %%
haikus_train_df
# Out:
#                                                   0  \
# 12344                          amoretti sonnet xxvi
# 12027      there when they came mind suffered shame
# 4696                              idle conversation
# 23120                        alone at sunrise . . .
# 9632   although there was no sound in all the house
# ...                                             ...
# 29802       My Grandpapa lives in a wonderful house
# 5390                           can i wash your hair
# 860                         the last light of day ~
# 15795      now every sound at length is hush'd away
# 23654                                quaker meeting
#
#                                                        1  \
# 12344                                                  e
# 12027                `these be the same and not the same
# 4696                               the daffodils nodding
# 23120                                a small wave covers
# 9632   i could not forbear listening for the cry of t...
# ...                                                  ...
# 29802  With a great many windows and doors, There are...
# 5390                                          underneath
# 860                                 purple rhododendrons
# 15795          these few are sacred moments one more day
# 23654                       through stovepipe-heated air
#
#                                                        2       source  \
# 12344                                            spenser    img2poems
# 12027                         a-wondering whispered mind    img2poems
# 4696                                       In the breeze  tempslibres
# 23120                                          my shadow      sballas
# 9632   dragging up their strength to break on the sul...    img2poems
# ...                                                  ...          ...
# 29802  stairs that go down, And such beautiful, slipp...    gutenberg
# 5390                                            that wig    img2poems
# 860                                 dissolve in the dark  tempslibres
# 15795         drops in the shadowy gulf of bygone things    img2poems
# 23654                                 the world shimmers      sballas
#
#        0_syllables  1_syllables  2_syllables  \
# 12344          7.0          1.0          2.0
# 12027          8.0          7.0          4.0
# 4696           6.0          6.0          3.0
# 23120          5.0          5.0          3.0
# 9632          10.0         18.0         15.0
# ...            ...          ...          ...
# 29802         11.0         16.0         12.0
# 5390           5.0          3.0          2.0
# 860            5.0          6.0          5.0
# 15795         10.0         10.0         11.0
# 23654          4.0          4.0          4.0
#
#                                                     text
# 12344                     amoretti sonnet xxvi e spenser
# 12027  there when they came mind suffered shame `thes...
# 4696   idle conversation the daffodils nodding In the...
# 23120  alone at sunrise . . . a small wave covers my ...
# 9632   although there was no sound in all the house i...
# ...                                                  ...
# 29802  My Grandpapa lives in a wonderful house With a...
# 5390            can i wash your hair underneath that wig
# 860    the last light of day ~ purple rhododendrons d...
# 15795  now every sound at length is hush'd away these...
# 23654  quaker meeting through stovepipe-heated air th...
#
# [25128 rows x 8 columns]

# %% [markdown]
# # Topic modelling with GloVe embeddings

# %%
from gensim.models import KeyedVectors, Doc2Vec
from gensim.scripts.glove2word2vec import glove2word2vec

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#vectorise with TF-IDF
tv = TfidfVectorizer(stop_words='english')

haiku_train_tv = tv.fit_transform(haikus_train_df['text'])
haiku_test_tv  = tv.transform(haikus_test_df['text'])

# %%
glove_file = './data/image_to_text/glove.840B.300d.txt'
tmp_file = './data/image_to_text/glovetmp.txt'

if not os.path.isfile(tmp_file):
    _ = glove2word2vec(glove_file, tmp_file)

glove_model = KeyedVectors.load_word2vec_format(tmp_file)
